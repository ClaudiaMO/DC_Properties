# %%
import pandas as pd
import numpy as np

# %%
location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
df.tail(3)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# 158954  1920.0   2007.0   ...     -77.01942            Old City 2
# 158955  1965.0      NaN   ...     -77.01823  Southwest Waterfront
# 158956  1965.0      NaN   ...     -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# 158954   040 B Old City 2        4801.0          NaN  Ward 6     477
# 158955                NaN       11000.0          NaN  Ward 6     504
# 158956                NaN       11000.0          NaN  Ward 6     504
#
#                 X          Y QUADRANT
# 158954 -77.019422  38.911848       NW
# ...

# %%
df.dropna(axis=1, how='all')
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
#drop a column
df.drop(columns=['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS',
       'BEDRM', 'AYB', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
       'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
        'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
       'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
       'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
       'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
       'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y'])
# Out:
#         ROOMS  YR_RMDL      CNDTN QUADRANT
# 0           8   1988.0       Good       NW
# 1          11   2007.0       Good       NW
# 2           9   2009.0  Very Good       NW
# 3           8   2003.0       Good       NW
# 4          11   2012.0       Good       NW
# 5          10      NaN       Good       NW
# 6           5   1988.0    Average       NW
# 7           8   2011.0    Average       NW
# 8           7   2008.0  Very Good       NW
# 9           6   1979.0    Average       NW
# 10         12   1950.0       Fair       NW
# 11         16      NaN    Average       NW
# 12          9   1979.0    Average       NW
# 13         11   1979.0    Average       NW
# 14          5   2000.0  Very Good       NW
# 15          9   1990.0    Average       NW
# 16          8   2006.0  Very Good       NW
# 17          6   1987.0    Average       NW
# 18         10   2006.0       Good       NW
# 19          9   2013.0       Good       NW
# 20         14   2009.0  Very Good       NW
# ...

# %%
df.groupby('QUADRANT')

# %%
df['ROOMS'].groupby(df['QUADRANT']).mean()
# Out:
# QUADRANT
# NE    6.500279
# NW    6.053702
# SE    6.375918
# SW    4.899878
# Name: ROOMS, dtype: float64

# %%
df['BEDRM'].groupby(df['QUADRANT']).mean()
# Out:
# QUADRANT
# NE    2.936430
# NW    2.662900
# SE    2.803703
# SW    1.863647
# Name: BEDRM, dtype: float64

# %%
df['FIREPLACES'].groupby(df['QUADRANT']).mean()
# Out:
# QUADRANT
# NE    0.452157
# NW    3.914616
# SE    0.314171
# SW    0.096940
# Name: FIREPLACES, dtype: float64

# %%
df['LANDAREA'].groupby(df['QUADRANT']).mean()
# Out:
# QUADRANT
# NE    2488.791321
# NW    2491.406660
# SE    2518.861776
# SW    1336.447001
# Name: LANDAREA, dtype: float64

# %%
df['ROOMS'].groupby(df['CNDTN']).mean()
# Out:
# CNDTN
# Average      7.121648
# Default      0.315789
# Excellent    8.652466
# Fair         7.260606
# Good         7.586474
# Poor         6.977143
# Very Good    8.143419
# Name: ROOMS, dtype: float64

# %%
df['LANDAREA'].groupby(df['CNDTN']).mean()
# Out:
# CNDTN
# Average       3069.403181
# Default      19111.263158
# Excellent     6495.943946
# Fair          3599.746970
# Good          3702.577860
# Poor          3858.794286
# Very Good     4000.886470
# Name: LANDAREA, dtype: float64

# %%
df['PRICE'].groupby(df['QUADRANT']).mean()
# Out:
# QUADRANT
# NE    3.928715e+05
# NW    1.317785e+06
# SE    3.682260e+05
# SW    3.470489e+05
# Name: PRICE, dtype: float64
